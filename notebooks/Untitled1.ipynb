# %%
from tensorflow import keras
import numpy as np
# Out:
# 2022-11-02 18:37:45.231292: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step

# %%
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
maxlen = 60
step = 3

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from tensorflow.keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# 2022-11-02 18:40:19.841666: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-02 18:40:19.842164: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-02 18:40:20.381351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.381504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2060 SUPER computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 34 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-11-02 18:40:20.381516: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-02 18:40:20.382333: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-02 18:40:20.382355: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-02 18:40:20.383146: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-02 18:40:20.383274: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-02 18:40:20.384053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-02 18:40:20.384481: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-02 18:40:20.386335: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-02 18:40:20.386397: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.386562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.386684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-02 18:40:20.386963: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-02 18:40:20.387364: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-02 18:40:20.387412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.387543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2060 SUPER computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 34 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-11-02 18:40:20.387553: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-02 18:40:20.387563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-02 18:40:20.387572: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-02 18:40:20.387581: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-02 18:40:20.387589: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-02 18:40:20.387598: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-02 18:40:20.387608: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-02 18:40:20.387616: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-02 18:40:20.387646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.387791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.387910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-02 18:40:20.387927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-02 18:40:20.740460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-02 18:40:20.740483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-11-02 18:40:20.740486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-11-02 18:40:20.740603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.740757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.740889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 18:40:20.741004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2060 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5)

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
        for i in range(400):
            
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# 2022-11-02 18:43:46.597203: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-11-02 18:43:46.621110: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3600000000 Hz
# 2022-11-02 18:43:47.405889: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-02 18:43:57.812152: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 28.5KiB (rounded to 29184)requested by op transpose_1
# Current allocation summary follows.
# 2022-11-02 18:43:57.812220: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2022-11-02 18:43:57.812247: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 28, Chunks in use: 27. 7.0KiB allocated for chunks. 6.8KiB in use in bin. 800B client-requested in use in bin.
# 2022-11-02 18:43:57.812267: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812285: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812302: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 8.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812318: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 5.2KiB allocated for chunks. 5.2KiB in use in bin. 4.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812333: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812353: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 5, Chunks in use: 5. 142.5KiB allocated for chunks. 142.5KiB in use in bin. 142.5KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812373: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 151.8KiB allocated for chunks. 151.8KiB in use in bin. 85.5KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812392: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 7, Chunks in use: 7. 570.0KiB allocated for chunks. 570.0KiB in use in bin. 548.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812411: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 142.0KiB allocated for chunks. 142.0KiB in use in bin. 114.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812429: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 768.0KiB allocated for chunks. 768.0KiB in use in bin. 768.0KiB client-requested in use in bin.
# 2022-11-02 18:43:57.812443: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812461: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.67MiB allocated for chunks. 1.67MiB in use in bin. 1.67MiB client-requested in use in bin.
# 2022-11-02 18:43:57.812481: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 2.58MiB allocated for chunks. 2.58MiB in use in bin. 1.67MiB client-requested in use in bin.
# 2022-11-02 18:43:57.812506: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812534: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812560: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812586: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812611: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812639: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812668: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:43:57.812698: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 28.5KiB was 16.0KiB, Chunk State:
# 2022-11-02 18:43:57.812720: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 6291456
# 2022-11-02 18:43:57.812750: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00000 of size 1280 next 1
# 2022-11-02 18:43:57.812776: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00500 of size 256 next 2
# 2022-11-02 18:43:57.812800: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00600 of size 256 next 9
# 2022-11-02 18:43:57.812841: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00700 of size 256 next 11
# 2022-11-02 18:43:57.812855: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00800 of size 256 next 16
# 2022-11-02 18:43:57.812867: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00900 of size 256 next 15
# 2022-11-02 18:43:57.812880: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00a00 of size 256 next 19
# 2022-11-02 18:43:57.812892: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00b00 of size 256 next 21
# 2022-11-02 18:43:57.812904: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00c00 of size 256 next 22
# 2022-11-02 18:43:57.812917: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00d00 of size 256 next 23
# 2022-11-02 18:43:57.812929: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00e00 of size 256 next 24
# 2022-11-02 18:43:57.812941: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00f00 of size 256 next 17
# 2022-11-02 18:43:57.812954: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01000 of size 2048 next 18
# 2022-11-02 18:43:57.812967: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01800 of size 256 next 25
# 2022-11-02 18:43:57.812979: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01900 of size 256 next 26
# 2022-11-02 18:43:57.812992: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01a00 of size 2048 next 29
# 2022-11-02 18:43:57.813005: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c02200 of size 55808 next 20
# 2022-11-02 18:43:57.813020: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c0fc00 of size 53760 next 3
# 2022-11-02 18:43:57.813033: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1ce00 of size 256 next 4
# 2022-11-02 18:43:57.813045: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1cf00 of size 256 next 5
# 2022-11-02 18:43:57.813057: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d000 of size 256 next 12
# 2022-11-02 18:43:57.813069: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d100 of size 256 next 6
# 2022-11-02 18:43:57.813081: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d200 of size 256 next 13
# 2022-11-02 18:43:57.813094: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d300 of size 256 next 30
# 2022-11-02 18:43:57.813105: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d400 of size 256 next 31
# 2022-11-02 18:43:57.813118: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d500 of size 256 next 32
# 2022-11-02 18:43:57.813133: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d600 of size 256 next 33
# 2022-11-02 18:43:57.813145: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d700 of size 256 next 34
# 2022-11-02 18:43:57.813157: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d800 of size 256 next 35
# 2022-11-02 18:43:57.813170: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d900 of size 2048 next 48
# 2022-11-02 18:43:57.813183: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1e100 of size 5376 next 37
# 2022-11-02 18:43:57.813195: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1f600 of size 256 next 38
# 2022-11-02 18:43:57.813207: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1f700 of size 2048 next 40
# 2022-11-02 18:43:57.813220: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1ff00 of size 29184 next 41
# 2022-11-02 18:43:57.813235: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c27100 of size 29184 next 42
# 2022-11-02 18:43:57.813247: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e300 of size 256 next 43
# 2022-11-02 18:43:57.813260: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fda86c2e400 of size 256 next 45
# 2022-11-02 18:43:57.813272: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e500 of size 256 next 46
# 2022-11-02 18:43:57.813285: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e600 of size 45824 next 7
# 2022-11-02 18:43:57.813298: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c39900 of size 116736 next 8
# 2022-11-02 18:43:57.813310: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c56100 of size 116736 next 27
# 2022-11-02 18:43:57.813324: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c72900 of size 145408 next 14
# 2022-11-02 18:43:57.813337: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c96100 of size 262144 next 10
# 2022-11-02 18:43:57.813353: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86cd6100 of size 262144 next 28
# 2022-11-02 18:43:57.813375: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d16100 of size 65536 next 47
# 2022-11-02 18:43:57.813398: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d26100 of size 29184 next 49
# 2022-11-02 18:43:57.813419: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d2d300 of size 29184 next 50
# 2022-11-02 18:43:57.813441: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34500 of size 29184 next 51
# 2022-11-02 18:43:57.813462: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d3b700 of size 65536 next 52
# 2022-11-02 18:43:57.813483: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d4b700 of size 65536 next 53
# 2022-11-02 18:43:57.813505: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d5b700 of size 65536 next 54
# 2022-11-02 18:43:57.813528: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d6b700 of size 88064 next 36
# 2022-11-02 18:43:57.813550: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d80f00 of size 262144 next 39
# 2022-11-02 18:43:57.813573: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86dc0f00 of size 1751040 next 44
# 2022-11-02 18:43:57.813597: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86f6c700 of size 2701568 next 18446744073709551615
# 2022-11-02 18:43:57.813618: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2022-11-02 18:43:57.813647: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 27 Chunks of size 256 totalling 6.8KiB
# 2022-11-02 18:43:57.813673: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-11-02 18:43:57.813700: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 2048 totalling 8.0KiB
# 2022-11-02 18:43:57.813725: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 5376 totalling 5.2KiB
# 2022-11-02 18:43:57.813751: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 29184 totalling 142.5KiB
# 2022-11-02 18:43:57.813777: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 45824 totalling 44.8KiB
# 2022-11-02 18:43:57.813802: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 53760 totalling 52.5KiB
# 2022-11-02 18:43:57.813826: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 55808 totalling 54.5KiB
# 2022-11-02 18:43:57.813852: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 65536 totalling 256.0KiB
# 2022-11-02 18:43:57.813878: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 88064 totalling 86.0KiB
# 2022-11-02 18:43:57.813903: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 116736 totalling 228.0KiB
# 2022-11-02 18:43:57.813929: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 145408 totalling 142.0KiB
# 2022-11-02 18:43:57.813955: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 262144 totalling 768.0KiB
# 2022-11-02 18:43:57.813981: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1751040 totalling 1.67MiB
# 2022-11-02 18:43:57.814005: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 2701568 totalling 2.58MiB
# 2022-11-02 18:43:57.814031: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 6.00MiB
# 2022-11-02 18:43:57.814054: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 6291456 memory_limit_: 6291456 available bytes: 0 curr_region_allocation_bytes_: 12582912
# 2022-11-02 18:43:57.814089: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                         6291456
# InUse:                         6291200
# MaxInUse:                      6291200
# NumAllocs:                          75
# MaxAllocSize:                  2701568
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-11-02 18:43:57.814128: W tensorflow/core/common_runtime/bfc_allocator.cc:441] *************************************************************************************xxxxxxxxxxxxxxx
# 2022-11-02 18:43:57.814183: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at transpose_op.cc:184 : Resource exhausted: OOM when allocating tensor with shape[128,57] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2022-11-02 18:44:07.814668: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.0KiB (rounded to 65536)requested by op transpose_5
# Current allocation summary follows.
# 2022-11-02 18:44:07.814728: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2022-11-02 18:44:07.814756: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 28, Chunks in use: 27. 7.0KiB allocated for chunks. 6.8KiB in use in bin. 800B client-requested in use in bin.
# 2022-11-02 18:44:07.814776: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 8, Chunks in use: 8. 4.0KiB allocated for chunks. 4.0KiB in use in bin. 4.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814793: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814810: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 8.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814827: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 1, Chunks in use: 0. 5.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.814842: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.814863: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 5, Chunks in use: 4. 138.5KiB allocated for chunks. 114.0KiB in use in bin. 114.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814883: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 151.8KiB allocated for chunks. 151.8KiB in use in bin. 85.5KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814902: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 7, Chunks in use: 7. 570.0KiB allocated for chunks. 570.0KiB in use in bin. 548.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814921: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 142.0KiB allocated for chunks. 142.0KiB in use in bin. 114.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814940: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 768.0KiB allocated for chunks. 768.0KiB in use in bin. 768.0KiB client-requested in use in bin.
# 2022-11-02 18:44:07.814957: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.814988: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.67MiB allocated for chunks. 1.67MiB in use in bin. 1.67MiB client-requested in use in bin.
# 2022-11-02 18:44:07.815020: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 2.58MiB allocated for chunks. 2.58MiB in use in bin. 1.67MiB client-requested in use in bin.
# 2022-11-02 18:44:07.815047: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815072: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815096: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815124: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815152: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815182: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815209: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-11-02 18:44:07.815241: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 64.0KiB was 64.0KiB, Chunk State:
# 2022-11-02 18:44:07.815267: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 6291456
# 2022-11-02 18:44:07.815288: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00000 of size 1280 next 1
# 2022-11-02 18:44:07.815303: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00500 of size 256 next 2
# 2022-11-02 18:44:07.815317: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00600 of size 256 next 9
# 2022-11-02 18:44:07.815330: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00700 of size 256 next 11
# 2022-11-02 18:44:07.815342: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00800 of size 256 next 16
# 2022-11-02 18:44:07.815354: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00900 of size 256 next 15
# 2022-11-02 18:44:07.815367: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00a00 of size 256 next 19
# 2022-11-02 18:44:07.815380: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00b00 of size 256 next 21
# 2022-11-02 18:44:07.815392: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00c00 of size 256 next 22
# 2022-11-02 18:44:07.815405: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00d00 of size 256 next 23
# 2022-11-02 18:44:07.815417: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00e00 of size 256 next 24
# 2022-11-02 18:44:07.815429: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c00f00 of size 256 next 17
# 2022-11-02 18:44:07.815442: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01000 of size 2048 next 18
# 2022-11-02 18:44:07.815456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01800 of size 256 next 25
# 2022-11-02 18:44:07.815468: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01900 of size 256 next 26
# 2022-11-02 18:44:07.815481: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c01a00 of size 2048 next 29
# 2022-11-02 18:44:07.815494: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c02200 of size 55808 next 20
# 2022-11-02 18:44:07.815508: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c0fc00 of size 53760 next 3
# 2022-11-02 18:44:07.815521: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1ce00 of size 256 next 4
# 2022-11-02 18:44:07.815533: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1cf00 of size 256 next 5
# 2022-11-02 18:44:07.815546: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d000 of size 256 next 12
# 2022-11-02 18:44:07.815558: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d100 of size 256 next 6
# 2022-11-02 18:44:07.815571: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d200 of size 256 next 13
# 2022-11-02 18:44:07.815584: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d300 of size 256 next 30
# 2022-11-02 18:44:07.815596: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d400 of size 256 next 31
# 2022-11-02 18:44:07.815609: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d500 of size 256 next 32
# 2022-11-02 18:44:07.815624: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d600 of size 256 next 33
# 2022-11-02 18:44:07.815637: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d700 of size 256 next 34
# 2022-11-02 18:44:07.815649: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d800 of size 256 next 35
# 2022-11-02 18:44:07.815662: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1d900 of size 2048 next 48
# 2022-11-02 18:44:07.815675: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fda86c1e100 of size 5376 next 37
# 2022-11-02 18:44:07.815689: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1f600 of size 256 next 38
# 2022-11-02 18:44:07.815702: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1f700 of size 2048 next 40
# 2022-11-02 18:44:07.815722: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c1ff00 of size 29184 next 41
# 2022-11-02 18:44:07.815748: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c27100 of size 29184 next 42
# 2022-11-02 18:44:07.815770: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e300 of size 256 next 43
# 2022-11-02 18:44:07.815792: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fda86c2e400 of size 256 next 45
# 2022-11-02 18:44:07.815814: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e500 of size 256 next 46
# 2022-11-02 18:44:07.815836: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c2e600 of size 45824 next 7
# 2022-11-02 18:44:07.815860: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c39900 of size 116736 next 8
# 2022-11-02 18:44:07.815882: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c56100 of size 116736 next 27
# 2022-11-02 18:44:07.815905: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c72900 of size 145408 next 14
# 2022-11-02 18:44:07.815928: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86c96100 of size 262144 next 10
# 2022-11-02 18:44:07.815949: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86cd6100 of size 262144 next 28
# 2022-11-02 18:44:07.815972: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d16100 of size 65536 next 47
# 2022-11-02 18:44:07.815995: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d26100 of size 29184 next 49
# 2022-11-02 18:44:07.816016: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d2d300 of size 29184 next 50
# 2022-11-02 18:44:07.816038: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34500 of size 512 next 55
# 2022-11-02 18:44:07.816059: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34700 of size 512 next 56
# 2022-11-02 18:44:07.816082: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34900 of size 512 next 57
# 2022-11-02 18:44:07.816104: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34b00 of size 512 next 58
# 2022-11-02 18:44:07.816125: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34d00 of size 512 next 59
# 2022-11-02 18:44:07.816146: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d34f00 of size 512 next 60
# 2022-11-02 18:44:07.816168: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d35100 of size 512 next 61
# 2022-11-02 18:44:07.816190: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d35300 of size 512 next 62
# 2022-11-02 18:44:07.816212: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fda86d35500 of size 25088 next 51
# 2022-11-02 18:44:07.816234: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d3b700 of size 65536 next 52
# 2022-11-02 18:44:07.816256: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d4b700 of size 65536 next 53
# 2022-11-02 18:44:07.816282: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d5b700 of size 65536 next 54
# 2022-11-02 18:44:07.816305: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d6b700 of size 88064 next 36
# 2022-11-02 18:44:07.816328: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86d80f00 of size 262144 next 39
# 2022-11-02 18:44:07.816351: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86dc0f00 of size 1751040 next 44
# 2022-11-02 18:44:07.816375: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fda86f6c700 of size 2701568 next 18446744073709551615
# 2022-11-02 18:44:07.816397: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2022-11-02 18:44:07.816424: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 27 Chunks of size 256 totalling 6.8KiB
# 2022-11-02 18:44:07.816450: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 8 Chunks of size 512 totalling 4.0KiB
# 2022-11-02 18:44:07.816476: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-11-02 18:44:07.816500: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 2048 totalling 8.0KiB
# 2022-11-02 18:44:07.816526: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 29184 totalling 114.0KiB
# 2022-11-02 18:44:07.816552: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 45824 totalling 44.8KiB
# 2022-11-02 18:44:07.816577: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 53760 totalling 52.5KiB
# 2022-11-02 18:44:07.816603: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 55808 totalling 54.5KiB
# 2022-11-02 18:44:07.816629: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 65536 totalling 256.0KiB
# 2022-11-02 18:44:07.816655: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 88064 totalling 86.0KiB
# 2022-11-02 18:44:07.816680: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 116736 totalling 228.0KiB
# 2022-11-02 18:44:07.816706: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 145408 totalling 142.0KiB
# 2022-11-02 18:44:07.816731: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 262144 totalling 768.0KiB
# 2022-11-02 18:44:07.816756: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1751040 totalling 1.67MiB
# 2022-11-02 18:44:07.816780: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 2701568 totalling 2.58MiB
# 2022-11-02 18:44:07.816804: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 5.97MiB
# 2022-11-02 18:44:07.816866: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 6291456 memory_limit_: 6291456 available bytes: 0 curr_region_allocation_bytes_: 12582912
# 2022-11-02 18:44:07.816902: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                         6291456
# InUse:                         6260736
# MaxInUse:                      6291200
# NumAllocs:                          86
# MaxAllocSize:                  2701568
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-11-02 18:44:07.816944: W tensorflow/core/common_runtime/bfc_allocator.cc:441] *************************************************************************************xxxxxxxxxxxxxxx
# 2022-11-02 18:44:07.816994: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at transpose_op.cc:184 : Resource exhausted: OOM when allocating tensor with shape[128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       4 for epoch in range(1, 60):
#       6     print('epoch', epoch)
# ----> 7     model.fit(x, y, batch_size=128, epochs=1)
#       8     start_index = random.randint(0, len(text) - maxlen - 1)
#       9     generated_text = text[start_index: start_index + maxlen]
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:888, in Function._call(self, *args, **kwds)
#     884     pass  # Fall through to cond-based initialization.
#     885   else:
#     886     # Lifting succeeded, so variables are initialized and we can run the
#     887     # stateless function.
# --> 888     return self._stateless_fn(*args, **kwds)
#     889 else:
#     890   _, _, _, filtered_flat_args = \
#     891       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     892           *args, **kwds)
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2942, in Function.__call__(self, *args, **kwargs)
#    2939 with self._lock:
#    2940   (graph_function,
#    2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# ResourceExhaustedError:    OOM when allocating tensor with shape[128,57] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node transpose_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[sequential/lstm/PartitionedCall]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_2963]
#
# Function call stack:
# train_function -> train_function -> train_function
